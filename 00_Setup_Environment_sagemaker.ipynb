# %%
# # Upgrade pip first
# !pip install --upgrade pip

# # Core AWS + Data Science packages
# !pip install boto3 awscli s3fs

# # Data processing & ML
# !pip install pandas numpy scikit-learn matplotlib seaborn

# # Optional (very useful for your project)
# !pip install tqdm joblib

# # If using SageMaker SDK explicitly
# !pip install sagemaker


# !pip install vaderSentiment

# !pip install vaderSentiment imbalanced-learn

# %%
import boto3
import pandas as pd
import numpy as np
import sklearn
import sagemaker

import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

print("boto3 version:", boto3.__version__)
print("pandas version:", pd.__version__)
print("sagemaker version:", sagemaker.__version__)

# Initialize the analyzer
analyzer = SentimentIntensityAnalyzer()

# Test it out
sample_text = "I love this Sephora lipstick, it's amazing!"
score = analyzer.polarity_scores(sample_text)

print("VADER is working!")
print(f"Test Score: {score}")
# Out:
# boto3 version: 1.37.3
# pandas version: 2.3.3
# sagemaker version: 2.245.0
# VADER is working!
# Test Score: {'neg': 0.0, 'neu': 0.376, 'pos': 0.624, 'compound': 0.8516}
